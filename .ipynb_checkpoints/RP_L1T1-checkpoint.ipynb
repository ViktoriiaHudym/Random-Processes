# %% [markdown]
# # Лабораторна робота №1. Моделювання випадкових величин.

# %% [markdown]
# # Завдання №1

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
import scipy.stats

# %% [markdown]
# ### Згенерувати послідовність з n =1000000 псевдовипадкових чисел, що рівномірно розподілені на інтервалі (0,1) (використати вбудований генератор псевдовипадкових чисел). Побудувати графік.

# %%
n = 1000000

# %%
numbers = np.random.uniform(0, 1, n)

# %% [markdown]
# Побудуємо графік для 10 000 випадкових чисел:

# %%
x = range(10000)
y = np.random.uniform(0, 1, size=10000)
plt.scatter(x, y, color='black', s=0.2)
plt.xlabel('Xn')
plt.ylabel('Xn+1')
plt.show()

# %% [markdown]
# ### Оцінити математичне сподівання та дисперсію отриманої послідовності.

# %% [markdown]
# Функція для знаходження математичного сподівання:

# %% [markdown]
# ![photo_2021-10-16_13-51-31.jpg](attachment:photo_2021-10-16_13-51-31.jpg)

# %%
def calc_Expectation(a, m):
    prb = 1 / m
    result = 0
    for i in range(0, m):
        result += (a[i] * prb)
    return float(result)

# %% [markdown]
# Функція для знаходження дисперсії:

# %% [markdown]
# ![photo_2021-10-16_13-56-40.jpg](attachment:photo_2021-10-16_13-56-40.jpg)

# %%
def calc_Variance(a, m):
    result = 0
    for i in range(0, m):
        result += ((a[i]-expect)**2/m)
    return float(result)

# %% [markdown]
# Передаємо значення аргументів у функції та виводимо на екран:

# %%
expect = calc_Expectation(numbers.flat, n)
variance = calc_Variance(numbers.flat, n)
print(f'\nMathematical expectation E(X): {round(expect, 6)}\n'
      f'The variance Var(X): {round(variance, 6)}')
# Out:
# Mathematical expectation E(X): 0.499557
# The variance Var(X): 0.083356

# %% [markdown]
# ### Побудувати таблицю 1 (кількість L підінтервалів не менше 10), частотну таблицю вивести на екран.

# %% [markdown]
# Обчислимо кількість інтервалів та крок. Виведемо значення на екран.

# %%
L = round(1+3.322*math.log10(n))
h = round(1/L, 5)
print(f'\nAmount of intervals = {L} \nSampling step = {h}')
# Out:
# Amount of intervals = 21
# Sampling step = 0.04762

# %%
intervals_b = []
intervals_e = []
quantity = []
relative_frequency = []

# %%
for interval in np.arange(0, 1.0, h):
    intervals_b.append(interval)
    if (interval + h) > 1:
        intervals_e.append(1.0)
    else:
        intervals_e.append(interval + h)
    q = numbers[(interval < numbers) & (numbers < interval+h)].size
    quantity.append(q)
    relative_frequency.append(q/n)

# %% [markdown]
# Задаємо макет результуючої таблиці, додаємо значення до кожної з колонок, виводимо на екран.

# %%
frequency_table = pd.DataFrame({
    'Left': intervals_b,
    'Right': intervals_e,
    'Quantity': quantity,
    'Relative frequency': relative_frequency
    }, index=pd.RangeIndex(start=1, stop=L+1))

# %%
count = sum(quantity)

# %%
print(f'\n{frequency_table}')
print(f'              Sum: {count}')
# Out:
#        Left    Right  Quantity  Relative frequency
# 1   0.00000  0.04762     47853            0.047853
# 2   0.04762  0.09524     47682            0.047682
# 3   0.09524  0.14286     47667            0.047667
# 4   0.14286  0.19048     47634            0.047634
# 5   0.19048  0.23810     47584            0.047584
# 6   0.23810  0.28572     47878            0.047878
# 7   0.28572  0.33334     47907            0.047907
# 8   0.33334  0.38096     47695            0.047695
# 9   0.38096  0.42858     47639            0.047639
# 10  0.42858  0.47620     47475            0.047475
# 11  0.47620  0.52382     47467            0.047467
# 12  0.52382  0.57144     47629            0.047629
# 13  0.57144  0.61906     47336            0.047336
# 14  0.61906  0.66668     47730            0.047730
# 15  0.66668  0.71430     47495            0.047495
# 16  0.71430  0.76192     47415            0.047415
# 17  0.76192  0.80954     47740            0.047740
# 18  0.80954  0.85716     47335            0.047335
# 19  0.85716  0.90478     47902            0.047902
# 20  0.90478  0.95240     47641            0.047641
# 21  0.95240  1.00000     47296            0.047296
#               Sum: 1000000

# %% [markdown]
# ### Перевірити гіпотезу про закон розподілу, побудувати гістограму.

# %% [markdown]
# Введемо функцію, що обчислює спостережуване значення ${\chi}^2$ за наступним алгоритмом:
# ![photo_2021-10-16_14-02-33.jpg](attachment:photo_2021-10-16_14-02-33.jpg)

# %%
def calc_chi_observable(sample, interval_left, q):
    average = calc_Expectation(sample.flat, n)
    standart_deviation = math.sqrt(calc_Variance(sample.flat, n))
    a = average - math.sqrt(3) * standart_deviation
    b = average + math.sqrt(3) * standart_deviation
    dencity_function = 1 / (b - a)

    nq = sum(q)

    critical_freq2 = []
    if nq * dencity_function * (interval_left[1] - a) > 0:
        n1 = nq * dencity_function * (interval_left[1] - a)
        critical_freq2.append((q[0] - n1) ** 2 / n1)
    else:
        critical_freq2.append(0.0)
    

    for idx in range(1, len(q)-1):
        ni = nq * (interval_left[idx] - interval_left[idx-1]) \
             / (b - a)
        critical_freq2.append((q[idx] - ni)**2/ni)
    
    ns = nq * dencity_function * (b - interval_left[-1])
    critical_freq2.append((q[-1] - ns) ** 2 / ns)

    return sum(critical_freq2)

# %% [markdown]
# Введемо функцію, що обчислює критичне значення ${\chi}^2$ (значення для $\alpha$ обрано 0.05):
# ![photo_2021-10-16_14-02-36.jpg](attachment:photo_2021-10-16_14-02-36.jpg)

# %%
def calc_chi_critical(alpha, s):
    result = scipy.stats.chi2.ppf(1 - alpha, s - 3)
    return result

# %% [markdown]
# При виконанні ${\chi}_{спост}^2$<${\chi}_{крит}^2$ розподіл є рівномірним. Визначимо функцію для цього кроку:

# %%
def is_uniform_distribution():
    chi_observable = calc_chi_observable(numbers, intervals_b, quantity)
    chi_critical = calc_chi_critical(0.05, L)
    print(f'\nChi observable = {chi_observable}\nChi critical = {chi_critical}')
    if chi_observable < chi_critical:
        return f'Chi observable < Chi critical. Distribution IS uniform'
    else:
        return f'Chi observable > Chi critical. Distribution IS NOT uniform'

# %% [markdown]
# Виведемо результат на екран:

# %%
print(is_uniform_distribution())
# Out:
# Chi observable = 12.879520345005702
# Chi critical = 28.869299430392623
# Chi observable < Chi critical. Distribution IS uniform

# %% [markdown]
# Побудуємо гістаграму:

# %%
fig, ax = plt.subplots()
plt.hist(numbers, bins=np.arange(0.0, 1.01, step=h), color='#ffff80', edgecolor='black')
plt.xticks(np.arange(0.0, 1.01, step=h), rotation='vertical')
fig.set_figwidth(10)
fig.set_figheight(6)
plt.show()

# %% [markdown]
# ### Дослідити розподіл випадкової величини $\eta$=max($\xi$), де $\xi$ - рівномірно розподілена на (0,1) випадкова величина, для цього:

# %% [markdown]
# #### **а)** змоделювати m=1000 значень величини $\eta$, знайти максимальне значення $\eta$1=max($\xi$);

# %% [markdown]
# #### **б)** процедуру а) повторити n=1000000;

# %%
m = 1000
arr = []

# %%
for i in range(n):
    mumbers = np.random.uniform(0, 1, size=m)
    arr.append(np.max(mumbers))

# %% [markdown]
# #### **в)** для випадкової величини $\eta$={$\eta$i, i=1...n} побудувати гістограму.

# %%
plt.hist(arr, bins=30, color='#ffff80', edgecolor='black')
plt.show()
